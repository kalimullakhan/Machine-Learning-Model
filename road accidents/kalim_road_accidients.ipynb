# %% [markdown]
# # Road Accidents India : 2017 - 2020¶
# The dataset is taken from the GOI site for Road and Transport Ministry for public safety.
# It reflects the number of accidents , their nature and the fatalities . It also looks into the numbers .
# shares and unit wise distribution of the calamity.The time span is from 2017 - 202
#
# Objective:
# Find Which State has highest Number of Road accident and plot the Graph of highest 20 State For All 4 Years.
#
# Find and Plot 5 state with least number of deathFor All 4 Years .
#
# Find Which State has highest Total Number of accident on lakh population For All 4 Years.
#
# Which State has highest Number of People Death in Road Accident For All 4 Years.
#
# Which State has highest Number of Injuiruies for All 4 Years

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\kalim khan\Desktop\imarticus learning\kalim imarticus learning\projects\road accidents\India_Injury_Road_Accident_Fatality_2017-2020.csv")

# %%
data.head()
# Out:
#                State  Road Accidents  during 2018  \
# 0     Andhra Pradesh                        24475
# 1  Arunachal Pradesh                          277
# 2              Assam                         8248
# 3              Bihar                         9600
# 4       Chhattisgarh                        13864
#
#     Road Accidents  during 2019  Road Accidents  during 2020  \
# 0                         21992                      19509.0
# 1                           237                        134.0
# 2                          8350                       6595.0
# 3                         10007                       8639.0
# 4                         13899                      11656.0
#
#    Accidents  Per Lakh Population - 2017  \
# 0                                   28.7
# 1                                   18.0
# 2                                   21.6
# 3                                    8.3
# 4                                   51.2
#
# ...

# %%
data.shape
# Out:
# (37, 45)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 45 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   State                                                  37 non-null     object
#  1   Road Accidents  during 2018                            37 non-null     int64
#  2    Road Accidents  during 2019                           37 non-null     int64
#  3   Road Accidents  during 2020                            36 non-null     float64
#  4   Accidents  Per Lakh Population - 2017                  36 non-null     float64
#  5   Total Number of Accidents  Per Lakh Population - 2018  36 non-null     float64
#  6   Total Number of Accidents  Per Lakh Population - 2019  36 non-null     float64
#  7   Total Number of Accidents  Per Lakh Population - 2020  36 non-null     float64
# ...

# %%
data.columns
# Out:
# Index(['State', 'Road Accidents  during 2018', ' Road Accidents  during 2019',
#        'Road Accidents  during 2020', 'Accidents  Per Lakh Population - 2017',
#        'Total Number of Accidents  Per Lakh Population - 2018',
#        'Total Number of Accidents  Per Lakh Population - 2019',
#        'Total Number of Accidents  Per Lakh Population - 2020',
#        'Accidents per 10,000 Vehicles - 2017',
#        'Accidents per 10,000 Vehicles - 2018',
#        'Accidents per 10,000 Vehicles - 2019',
#        'Accidents per 10,000 Km of Roads - 2017',
#        'Accidents per 10,000 Km of Roads - 2018', 'Persons Killed 2017',
#        'Persons Killed 2018', 'Persons Killed 2019', 'Persons Killed 2020',
#        'Share in Death- 2017', 'Share in Death- 2018', 'Share in Death- 2019',
#        'Share in Death- 2020', 'Persons Killed Per Lakh Population - 2017',
#        'Persons Killed Per Lakh Population - 2018',
#        'Persons Killed Per Lakh Population - 2019',
# ...

# %% [markdown]
# # now will clean the data

# %%
data.isnull().sum()
# Out:
# State                                                    0
# Road Accidents  during 2018                              0
#  Road Accidents  during 2019                             0
# Road Accidents  during 2020                              1
# Accidents  Per Lakh Population - 2017                    1
# Total Number of Accidents  Per Lakh Population - 2018    1
# Total Number of Accidents  Per Lakh Population - 2019    1
# Total Number of Accidents  Per Lakh Population - 2020    1
# Accidents per 10,000 Vehicles - 2017                     0
# Accidents per 10,000 Vehicles - 2018                     1
# Accidents per 10,000 Vehicles - 2019                     1
# Accidents per 10,000 Km of Roads - 2017                  0
# Accidents per 10,000 Km of Roads - 2018                  0
# Persons Killed 2017                                      0
# Persons Killed 2018                                      0
# Persons Killed 2019                                      0
# ...

# %%
data.dropna(axis=0,how='any',inplace=True)

# %%
data.isnull().sum()
# Out:
# State                                                    0
# Road Accidents  during 2018                              0
#  Road Accidents  during 2019                             0
# Road Accidents  during 2020                              0
# Accidents  Per Lakh Population - 2017                    0
# Total Number of Accidents  Per Lakh Population - 2018    0
# Total Number of Accidents  Per Lakh Population - 2019    0
# Total Number of Accidents  Per Lakh Population - 2020    0
# Accidents per 10,000 Vehicles - 2017                     0
# Accidents per 10,000 Vehicles - 2018                     0
# Accidents per 10,000 Vehicles - 2019                     0
# Accidents per 10,000 Km of Roads - 2017                  0
# Accidents per 10,000 Km of Roads - 2018                  0
# Persons Killed 2017                                      0
# Persons Killed 2018                                      0
# Persons Killed 2019                                      0
# ...

# %%
data.shape
# Out:
# (35, 45)

# %%
data.columns=[i.replace(' ','_')for i in data.columns]
data.columns
# Out:
# Index(['State', 'Road_Accidents__during_2018', '_Road_Accidents__during_2019',
#        'Road_Accidents__during_2020', 'Accidents__Per_Lakh_Population_-_2017',
#        'Total_Number_of_Accidents__Per_Lakh_Population_-_2018',
#        'Total_Number_of_Accidents__Per_Lakh_Population_-_2019',
#        'Total_Number_of_Accidents__Per_Lakh_Population_-_2020',
#        'Accidents_per_10,000_Vehicles_-_2017',
#        'Accidents_per_10,000_Vehicles_-_2018',
#        'Accidents_per_10,000_Vehicles_-_2019',
#        'Accidents_per_10,000_Km_of_Roads_-_2017',
#        'Accidents_per_10,000_Km_of_Roads_-_2018', 'Persons_Killed_2017',
#        'Persons_Killed_2018', 'Persons_Killed_2019', 'Persons_Killed_2020',
#        'Share_in_Death-_2017', 'Share_in_Death-_2018', 'Share_in_Death-_2019',
#        'Share_in_Death-_2020', 'Persons_Killed_Per_Lakh_Population_-_2017',
#        'Persons_Killed_Per_Lakh_Population_-_2018',
#        'Persons_Killed_Per_Lakh_Population_-_2019',
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.sort_values(by='Road_Accidents__during_2018',ascending=False)
# Out:
#                           State  Road_Accidents__during_2018  \
# 36                       Total                        467044
# 23                   Tamil Nadu                        63920
# 13               Madhya Pradesh                        51397
# 27                Uttar Pradesh                        42568
# 11                    Karnataka                        41707
# 12                       Kerala                        40181
# 14                  Maharashtra                        35717
# 0                Andhra Pradesh                        24475
# 21                    Rajasthan                        21743
# 6                       Gujarat                        18769
# 4                  Chhattisgarh                        13864
# 28                  West Bengal                        12705
# 19                       Odisha                        11262
# 7                       Haryana                        11238
# ...

# %% [markdown]
# # Find Which State has highest Number of Road accident in Year 2018 and plot the Graph of highest 20 State.

# %%
highest_acc_2018=data.sort_values('Road_Accidents__during_2018',ascending=False)[1:21]
highest_acc_2018
# Out:
#                 State  Road_Accidents__during_2018  \
# 23         Tamil Nadu                        63920
# 13     Madhya Pradesh                        51397
# 27      Uttar Pradesh                        42568
# 11          Karnataka                        41707
# 12             Kerala                        40181
# 14        Maharashtra                        35717
# 0      Andhra Pradesh                        24475
# 21          Rajasthan                        21743
# 6             Gujarat                        18769
# 4        Chhattisgarh                        13864
# 28        West Bengal                        12705
# 19             Odisha                        11262
# 7             Haryana                        11238
# 3               Bihar                         9600
# 2               Assam                         8248
# 33              Delhi                         6515
# 20             Punjab                         6428
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=highest_acc_2018,x='State',y='Road_Accidents__during_2018')
plt.title("Highest Accident in 2018 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Accidents During 2018',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=45)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # - Tamil Nadu has highest Number of Road accidents in year 2018. The possible reasons are the large poplulation that are residing in the stat

# %%
low_acc_2018=data.sort_values(by='Road_Accidents__during_2018')[:5]
low_acc_2018
# Out:
#                           State  Road_Accidents__during_2018  \
# 34                  Lakshadweep                            3
# 17                      Mizoram                           53
# 31       Dadra and Nagar Haveli                           80
# 22                       Sikkim                          180
# 29  Andaman and Nicobar Islands                          254
#
#     _Road_Accidents__during_2019  Road_Accidents__during_2020  \
# 34                             1                          1.0
# 17                            62                         53.0
# 31                            68                        100.0
# 22                           162                        138.0
# 29                           230                        141.0
#
#     Accidents__Per_Lakh_Population_-_2017  \
# 34                                    1.2
# 17                                    6.3
# 31                                   14.8
# 22                                   29.7
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=low_acc_2018,x='State',y='Road_Accidents__during_2018')
plt.title("Lowest Accident in 2018 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Accidents During 2018',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # - The reasons for the lowest accident in these states are less population and presence of less vehicles.

# %% [markdown]
# # Find Which State has highest Number of Road accident in Year 2019 and plot the Graph of highest 20 State

# %%
highest_acc_2019=data.sort_values('_Road_Accidents__during_2019',ascending=False)[1:21]
highest_acc_2019
# Out:
#                 State  Road_Accidents__during_2018  \
# 23         Tamil Nadu                        63920
# 13     Madhya Pradesh                        51397
# 27      Uttar Pradesh                        42568
# 12             Kerala                        40181
# 11          Karnataka                        41707
# 14        Maharashtra                        35717
# 21          Rajasthan                        21743
# 0      Andhra Pradesh                        24475
# 6             Gujarat                        18769
# 4        Chhattisgarh                        13864
# 19             Odisha                        11262
# 7             Haryana                        11238
# 28        West Bengal                        12705
# 3               Bihar                         9600
# 2               Assam                         8248
# 20             Punjab                         6428
# 9   Jammu and Kashmir                         5978
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=highest_acc_2019,x='State',y='_Road_Accidents__during_2019',color='red')
plt.title("Highest Accident in 2019 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Accidents During 2019',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=45)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # In the above graph it shows highest number of accidents during 2019 is Tamilnadu

# %% [markdown]
# # Find Which State has highest Number of Road accident in Year 2020 and plot the Graph of highest 20 States.

# %%
highest_acc_2020=data.sort_values('Road_Accidents__during_2020',ascending=False)[1:21]
highest_acc_2019
# Out:
#                 State  Road_Accidents__during_2018  \
# 23         Tamil Nadu                        63920
# 13     Madhya Pradesh                        51397
# 27      Uttar Pradesh                        42568
# 12             Kerala                        40181
# 11          Karnataka                        41707
# 14        Maharashtra                        35717
# 21          Rajasthan                        21743
# 0      Andhra Pradesh                        24475
# 6             Gujarat                        18769
# 4        Chhattisgarh                        13864
# 19             Odisha                        11262
# 7             Haryana                        11238
# 28        West Bengal                        12705
# 3               Bihar                         9600
# 2               Assam                         8248
# 20             Punjab                         6428
# 9   Jammu and Kashmir                         5978
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=highest_acc_2020,x='State',y='Road_Accidents__during_2020')
plt.title("Highest Accident in 2020 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Accidents During 2020',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # In the year 2020 Highest number of accidients has been occured in TamilNadu

# %% [markdown]
# # Conclusion 1:
# Tamil Nadu followed by Madhya Pradesh and Uttar Pradesh has highest number of road accident in these three year.
#
# The number of accident are decresasing year by year which is a good sign

# %%
data.head()
# Out:
#                State  Road_Accidents__during_2018  \
# 0     Andhra Pradesh                        24475
# 1  Arunachal Pradesh                          277
# 2              Assam                         8248
# 3              Bihar                         9600
# 4       Chhattisgarh                        13864
#
#    _Road_Accidents__during_2019  Road_Accidents__during_2020  \
# 0                         21992                      19509.0
# 1                           237                        134.0
# 2                          8350                       6595.0
# 3                         10007                       8639.0
# 4                         13899                      11656.0
#
#    Accidents__Per_Lakh_Population_-_2017  \
# 0                                   28.7
# 1                                   18.0
# 2                                   21.6
# 3                                    8.3
# 4                                   51.2
#
# ...

# %% [markdown]
# # Find Which State has highest Total Number of accident on lakh population in 2017

# %%
total_acc_lakh_2017=data.sort_values(by='Accidents__Per_Lakh_Population_-_2017',ascending=False)[1:21]
total_acc_lakh_2017
# Out:
#                           State  Road_Accidents__during_2018  \
# 12                       Kerala                        40181
# 35                   Puducherry                         1597
# 23                   Tamil Nadu                        63920
# 11                    Karnataka                        41707
# 13               Madhya Pradesh                        51397
# 4                  Chhattisgarh                        13864
# 9             Jammu and Kashmir                         5978
# 8              Himachal Pradesh                         3110
# 7                       Haryana                        11238
# 36                       Total                        467044
# 29  Andaman and Nicobar Islands                          254
# 6                       Gujarat                        18769
# 22                       Sikkim                          180
# 33                        Delhi                         6515
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=total_acc_lakh_2017,x='State',y='Accidents__Per_Lakh_Population_-_2017')
plt.title("Highest Total Number of Lakh Accident in 2017 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Total Number of Lakh Accident in 2017',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # Find Which State has highest Total Number of accident on lakh population in 2018

# %%
total_acc_lakh_2018=data.sort_values(by='Total_Number_of_Accidents__Per_Lakh_Population_-_2018',ascending=False)[1:21]
total_acc_lakh_2018
# Out:
#                           State  Road_Accidents__during_2018  \
# 12                       Kerala                        40181
# 23                   Tamil Nadu                        63920
# 35                   Puducherry                         1597
# 11                    Karnataka                        41707
# 13               Madhya Pradesh                        51397
# 4                  Chhattisgarh                        13864
# 9             Jammu and Kashmir                         5978
# 29  Andaman and Nicobar Islands                          254
# 8              Himachal Pradesh                         3110
# 7                       Haryana                        11238
# 36                       Total                        467044
# 6                       Gujarat                        18769
# 21                    Rajasthan                        21743
# 14                  Maharashtra                        35717
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=total_acc_lakh_2018,x='State',y='Total_Number_of_Accidents__Per_Lakh_Population_-_2018')
plt.title("Highest Total Number of Lakh Accident in 2018 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Total Number of Lakh Accident in 2018',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # Find Which State has highest Total Number of accident on lakh population in 2019

# %%
total_acc_lakh_2019=data.sort_values(by='Total_Number_of_Accidents__Per_Lakh_Population_-_2019',ascending=False)[1:21]
total_acc_lakh_2019
# Out:
#                           State  Road_Accidents__during_2018  \
# 12                       Kerala                        40181
# 23                   Tamil Nadu                        63920
# 35                   Puducherry                         1597
# 11                    Karnataka                        41707
# 13               Madhya Pradesh                        51397
# 4                  Chhattisgarh                        13864
# 9             Jammu and Kashmir                         5978
# 8              Himachal Pradesh                         3110
# 29  Andaman and Nicobar Islands                          254
# 7                       Haryana                        11238
# 36                       Total                        467044
# 21                    Rajasthan                        21743
# 14                  Maharashtra                        35717
# 6                       Gujarat                        18769
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=total_acc_lakh_2019,x='State',y='Total_Number_of_Accidents__Per_Lakh_Population_-_2019')
plt.title("Highest Total Number of Lakh Accident in 2019 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Total Number of Lakh Accident in 2019',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # Find Which State has highest Total Number of accident on lakh population in 2020

# %%
total_acc_lakh_2020=data.sort_values(by='Total_Number_of_Accidents__Per_Lakh_Population_-_2020',ascending=False)[1:21]
total_acc_lakh_2020
# Out:
#                           State  Road_Accidents__during_2018  \
# 12                       Kerala                        40181
# 23                   Tamil Nadu                        63920
# 13               Madhya Pradesh                        51397
# 11                    Karnataka                        41707
# 35                   Puducherry                         1597
# 4                  Chhattisgarh                        13864
# 9             Jammu and Kashmir                         5978
# 7                       Haryana                        11238
# 8              Himachal Pradesh                         3110
# 36                       Total                        467044
# 21                    Rajasthan                        21743
# 29  Andaman and Nicobar Islands                          254
# 19                       Odisha                        11262
# 0                Andhra Pradesh                        24475
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=total_acc_lakh_2020,x='State',y='Total_Number_of_Accidents__Per_Lakh_Population_-_2020')
plt.title("Highest Total Number of Lakh Accident in 2020 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Total Number of Lakh Accident in 2020',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # Conclusions 2:
# From the graph we can conclude that:
#
# Kerela has highest total number per lakh accident.
#
# For the first three year i.e,2017,2018,2019 kerela has accident rate above 100 and its increasing but for the year 2020 its accident rates drops significantly. this may be because of the fact that there is lockdown in whole country. so its one of the reason due to which the total number of accident in 2020 are much lesser than other year for kerela and other states also.
#
# In 2017 Puducherry has second highest total number of accident but with increasing year it controls the accidents

# %% [markdown]
# # Which State has highest Number of People Death in Road Accident in year 2017

# %%
person_death_2017=data.sort_values(by='Persons_Killed_2017',ascending=False)[1:11]
person_death_2017
# Out:
#              State  Road_Accidents__during_2018  _Road_Accidents__during_2019  \
# 27   Uttar Pradesh                        42568                         42572
# 23      Tamil Nadu                        63920                         57228
# 14     Maharashtra                        35717                         32925
# 11       Karnataka                        41707                         40658
# 21       Rajasthan                        21743                         23480
# 13  Madhya Pradesh                        51397                         50669
# 0   Andhra Pradesh                        24475                         21992
# 6          Gujarat                        18769                         17046
# 28     West Bengal                        12705                         10158
# 3            Bihar                         9600                         10007
#
#     Road_Accidents__during_2020  Accidents__Per_Lakh_Population_-_2017  \
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=person_death_2017,x='State',y='Persons_Killed_2017')
plt.title("Highest Number of Death in Road Accident in 2017 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Number of Death in Road Accident in 2017',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # Which State has highest Number of People Death in Road Accident in year 2018

# %%
person_death_2018=data.sort_values(by='Persons_Killed_2017',ascending=False)[1:11]
person_death_2018
# Out:
#              State  Road_Accidents__during_2018  _Road_Accidents__during_2019  \
# 27   Uttar Pradesh                        42568                         42572
# 23      Tamil Nadu                        63920                         57228
# 14     Maharashtra                        35717                         32925
# 11       Karnataka                        41707                         40658
# 21       Rajasthan                        21743                         23480
# 13  Madhya Pradesh                        51397                         50669
# 0   Andhra Pradesh                        24475                         21992
# 6          Gujarat                        18769                         17046
# 28     West Bengal                        12705                         10158
# 3            Bihar                         9600                         10007
#
#     Road_Accidents__during_2020  Accidents__Per_Lakh_Population_-_2017  \
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=person_death_2018,x='State',y='Persons_Killed_2018')
plt.title("Highest Number of Death in Road Accident in 2018 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Number of Death in Road Accident in 2018',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # Which State has highest Number of People Death in Road Accident in year 2019

# %%
person_death_2019=data.sort_values(by='Persons_Killed_2017',ascending=False)[1:11]
person_death_2019
# Out:
#              State  Road_Accidents__during_2018  _Road_Accidents__during_2019  \
# 27   Uttar Pradesh                        42568                         42572
# 23      Tamil Nadu                        63920                         57228
# 14     Maharashtra                        35717                         32925
# 11       Karnataka                        41707                         40658
# 21       Rajasthan                        21743                         23480
# 13  Madhya Pradesh                        51397                         50669
# 0   Andhra Pradesh                        24475                         21992
# 6          Gujarat                        18769                         17046
# 28     West Bengal                        12705                         10158
# 3            Bihar                         9600                         10007
#
#     Road_Accidents__during_2020  Accidents__Per_Lakh_Population_-_2017  \
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=person_death_2019,x='State',y='Persons_Killed_2019')
plt.title("Highest Number of Death in Road Accident in 2019 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Number of Death in Road Accident in 2018',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # Which State has highest Number of People Death in Road Accident in year 2020

# %%
person_death_2020=data.sort_values(by='Persons_Killed_2017',ascending=False)[1:11]
person_death_2020
# Out:
#              State  Road_Accidents__during_2018  _Road_Accidents__during_2019  \
# 27   Uttar Pradesh                        42568                         42572
# 23      Tamil Nadu                        63920                         57228
# 14     Maharashtra                        35717                         32925
# 11       Karnataka                        41707                         40658
# 21       Rajasthan                        21743                         23480
# 13  Madhya Pradesh                        51397                         50669
# 0   Andhra Pradesh                        24475                         21992
# 6          Gujarat                        18769                         17046
# 28     West Bengal                        12705                         10158
# 3            Bihar                         9600                         10007
#
#     Road_Accidents__during_2020  Accidents__Per_Lakh_Population_-_2017  \
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=person_death_2020,x='State',y='Persons_Killed_2020')
plt.title("Highest Number of Death in Road Accident in 2020 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Number of Death in Road Accident in 2018',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # Conclusion 3:
# Uttar Pradesh,Maharastra,Madhya Pradesh and Karnataka are the top 4 states with the most number of people death.

# %% [markdown]
# # Which State has highest Number of Injuries in 2017

# %%
injuries_df_2017=data.sort_values(by='Persons_Injured_-_2017',ascending=False)[1:11]
injuries_df_2017
# Out:
#              State  Road_Accidents__during_2018  _Road_Accidents__during_2019  \
# 23      Tamil Nadu                        63920                         57228
# 13  Madhya Pradesh                        51397                         50669
# 11       Karnataka                        41707                         40658
# 12          Kerala                        40181                         41111
# 14     Maharashtra                        35717                         32925
# 27   Uttar Pradesh                        42568                         42572
# 0   Andhra Pradesh                        24475                         21992
# 21       Rajasthan                        21743                         23480
# 6          Gujarat                        18769                         17046
# 4     Chhattisgarh                        13864                         13899
#
#     Road_Accidents__during_2020  Accidents__Per_Lakh_Population_-_2017  \
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=injuries_df_2017,x='State',y='Persons_Injured_-_2017')
plt.title("Highest Number of Persons_Injured in 2017 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Number of Death in Persons Injured in 2017',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # Which State has highest Number of Injuries in 2018

# %%
injuries_df_2018=data.sort_values(by='Persons_Injured_-_2017',ascending=False)[1:11]
injuries_df_2018
# Out:
#              State  Road_Accidents__during_2018  _Road_Accidents__during_2019  \
# 23      Tamil Nadu                        63920                         57228
# 13  Madhya Pradesh                        51397                         50669
# 11       Karnataka                        41707                         40658
# 12          Kerala                        40181                         41111
# 14     Maharashtra                        35717                         32925
# 27   Uttar Pradesh                        42568                         42572
# 0   Andhra Pradesh                        24475                         21992
# 21       Rajasthan                        21743                         23480
# 6          Gujarat                        18769                         17046
# 4     Chhattisgarh                        13864                         13899
#
#     Road_Accidents__during_2020  Accidents__Per_Lakh_Population_-_2017  \
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=injuries_df_2018,x='State',y='Persons_Injured_-_2018')
plt.title("Highest Number of Persons_Injured in 2018 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Number of Death in Persons Injured in 2018',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # Which State has highest Number of Injuries in 2019

# %%
injuries_df_2019=data.sort_values(by='Persons_Injured_-_2019',ascending=False)[1:11]
injuries_df_2019
# Out:
#              State  Road_Accidents__during_2018  _Road_Accidents__during_2019  \
# 23      Tamil Nadu                        63920                         57228
# 13  Madhya Pradesh                        51397                         50669
# 11       Karnataka                        41707                         40658
# 12          Kerala                        40181                         41111
# 27   Uttar Pradesh                        42568                         42572
# 14     Maharashtra                        35717                         32925
# 0   Andhra Pradesh                        24475                         21992
# 21       Rajasthan                        21743                         23480
# 6          Gujarat                        18769                         17046
# 4     Chhattisgarh                        13864                         13899
#
#     Road_Accidents__during_2020  Accidents__Per_Lakh_Population_-_2017  \
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=injuries_df_2019,x='State',y='Persons_Injured_-_2019')
plt.title("Highest Number of Persons_Injured in 2019 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Number of Death in Persons Injured in 2019',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # Which State has highest Number of Injuries in 2019

# %%
injuries_df_2020=data.sort_values(by='Persons_Injured_-_2020',ascending=False)[1:11]
injuries_df_2020
# Out:
#              State  Road_Accidents__during_2018  _Road_Accidents__during_2019  \
# 23      Tamil Nadu                        63920                         57228
# 13  Madhya Pradesh                        51397                         50669
# 11       Karnataka                        41707                         40658
# 12          Kerala                        40181                         41111
# 27   Uttar Pradesh                        42568                         42572
# 14     Maharashtra                        35717                         32925
# 0   Andhra Pradesh                        24475                         21992
# 21       Rajasthan                        21743                         23480
# 6          Gujarat                        18769                         17046
# 4     Chhattisgarh                        13864                         13899
#
#     Road_Accidents__during_2020  Accidents__Per_Lakh_Population_-_2017  \
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=injuries_df_2020,x='State',y='Persons_Injured_-_2020')
plt.title("Highest Number of Persons_Injured in 2020 State Wise",fontsize=14,pad=14)
plt.xlabel('State',fontsize=12)
plt.ylabel('Number of Death in Persons Injured in 2020',fontsize=12)

plt.tick_params(axis='x',which='major',labelsize=12,rotation=90)
plt.tick_params(axis='y',which='major',labelsize=12)

# %% [markdown]
# # Conclusion 4:
#
# - Tamil Nadu,Madhya Pradesh and KArnataka are the State which have most number of Injuried People during road accident.
